# %% [markdown]
# # Resnet Classification of Fruit or Vegetable using KNN
# ## Steps
# - Get Fruit Veg Dataset From Kaggle
# - Finetune Resnet on New Dataset
# - Chop off last layer of resnet to be KNN
